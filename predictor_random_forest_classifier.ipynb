# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from dependencies import *

# %%
X = []
Y = []

collect_images_from_files(X, Y)

# %%
X = np.array(X)
Y = np.array(Y)
X.shape
# Out:
# (394, 200, 200)

# %%
# Sklearn accepts only bidiomensional data, so we have to convert it

X_reshape = X.reshape(len(X), -1)
X_reshape.shape
# Out:
# (394, 40000)

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X_reshape, Y, random_state=10, test_size=.2)

# %%
xTrain.shape, xTest.shape
# Out:
# ((315, 40000), (79, 40000))

# %%
xTrain, xTest = scale_data_tests(xTrain, xTest)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(xTrain, yTrain)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
classifier.score(xTest, yTest)
# Out:
# 0.810126582278481

# %%
test_based_on_images(classifier, 'no_tumor/')

# %%
test_based_on_images(classifier, 'pituitary_tumor/')

# %%
test_based_on_images(classifier, 'meningioma_tumor/')

# %%
test_based_on_images(classifier, 'glioma_tumor/')

# %%
test_based_on_images(classifier, 'brain_tumor/', 20)
